# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 1D plotting:
x = np.linspace(0, 3, 20)
y = np.linspace(0, 9, 20)
plt.plot(x, y, 'o')
plt.plot(x, y)

# %%
# 2D arrays

# %%
image = np.random.rand(30, 30)
# image = np.random.randn(30, 30)
# image = np.linspace(0,100,900).reshape(30, 30)
plt.imshow(image, cmap=plt.cm.hot) 
plt.colorbar()

# %%
# length of vector
a = np.array([2,5])
np.linalg.norm(a)
# Out:
# 5.3851648071345037

# %%
data = np.loadtxt('populations.txt')
year, hares, lynxes, carrots = data.T

# %%
plt.axes([0.2, 0.1, 0.5, 0.8])
plt.plot(year, hares, year, lynxes, year, carrots)
plt.legend(('Hare', 'Lynx', 'Carrot'), loc=(1.05, 0.5))

# %%
data[:, 1:].mean(axis=0)
# Out:
# array([ 34080.95238095,  20166.66666667,  42400.        ])

# %%
x = np.ma.array([1, 2, 3, 4], mask=[0, 1, 0, 1])
x
# Out:
# masked_array(data = [1 -- 3 --],
#              mask = [False  True False  True],
#        fill_value = 999999)

# %%
pwd
# Out:
# u'D:\\source\\playfield\\py\\numpy'

# %%
ls
# Out:
#  Volume in drive D is #D
#  Volume Serial Number is DC4B-7055
#
#  Directory of D:\source\playfield\py\numpy
#
# 06/23/2016  05:50 PM    <DIR>          .
# 06/23/2016  05:50 PM    <DIR>          ..
# 06/23/2016  11:06 AM    <DIR>          .ipynb_checkpoints
# 06/23/2016  05:50 PM           167,835 Basic visualization.ipynb
# 06/21/2016  03:01 PM            21,088 numpy-exercises.ipynb
# 06/23/2016  05:37 PM               525 populations.txt
#                3 File(s)        189,448 bytes
#                3 Dir(s)  716,479,569,920 bytes free

# %%
data = np.ones((3, 3))
np.save('pop.npy', data)
np.load('pop.npy')
# Out:
# array([[ 1.,  1.,  1.],
#        [ 1.,  1.,  1.],
#        [ 1.,  1.,  1.]])
